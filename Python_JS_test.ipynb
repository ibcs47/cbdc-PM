# %%
import js2py
from py_mini_racer import MiniRacer

# %%
  
code_2 = """
function f(x) {return x+x;}
"""
res_2 = js2py.eval_js(code_2)
  
print(res_2(5))
# Out:
# 10

# %%
sign = """
const jsutil = require('ethereumjs-util');

console.log(process.argv);

if (process.argv.length <= 3) {
    console.log(process.argv);
    console.error('ERROR: Insufficient number of arguments');
    console.error('Usage: node sign_home_native_message.js <keyIndex> <...message parts>');
    process.exit(1);
}

const keyPairs = require('./keys.json').keypair;
const signingKeyIndex = process.argv[2];

if ((signingKeyIndex < 0) || (signingKeyIndex >= keyPairs.length)) {
    console.error(`ERROR: Key index out of range [0,${keyPairs.length - 1}]`);
    process.exit(1);
}

var signingKey = keyPairs[signingKeyIndex].privateKeyString;
if (signingKey.startsWith('0x')) {
    signingKey = signingKey.substring(2);
}

const messageParts = process.argv.slice(3);
const message = Buffer.from(messageParts.map(a => a.toString()).join(' '));

const messageHash = jsutil.hashPersonalMessage(message);
const keyBuffer = Buffer.from(signingKey, 'hex');
const signature = jsutil.ecsign(messageHash, keyBuffer);

console.log("Signature v: " + signature.v);
console.log("Signature r (base64): " + signature.r.toString("base64"));
console.log("Signature s (base64): " + signature.s.toString("base64"));
"""

# %%
res_s = js2py.eval_js(sign)
  
print(res_s(0, 0x1b18cf7b9bd974a9b2f2c4d5c0b1c2f69022dc2b, 0xa48c6cc002b627954e1862620544e5613874676b, 5, default, 20))
# Out:
# ---------------------------------------------------------------------------
# Ecma51NotSupported                        Traceback (most recent call last)
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parse(self, code, options)
#    3007         try:
# -> 3008             program = self.parseProgram()
#    3009         except Ecma51NotSupported as e:
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parseProgram(self)
#    2973
# -> 2974         body = self.parseScriptBody()
#    2975         return node.finishProgram(body)
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parseScriptBody(self)
#    2962         while (self.startIndex < self.length):
# -> 2963             statement = self.parseStatementListItem()
#    2964             # istanbul ignore if
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parseStatementListItem(self)
#    2109                 return self.parsePyimportStatement()
# -> 2110         return self.parseStatement()
#    2111
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parseStatement(self)
#    2688             elif val == 'if':
# -> 2689                 return self.parseIfStatement(node)
#    2690             elif val == 'return':
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parseIfStatement(self, node)
#    2276
# -> 2277         consequent = self.parseStatement()
#    2278
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parseStatement(self)
#    2663         if (typ == Token.Punctuator and self.lookahead['value'] == '{'):
# -> 2664             return self.parseBlock()
#    2665
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parseBlock(self)
#    2133
# -> 2134         block = self.parseStatementList()
#    2135
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parseStatementList(self)
#    2125                 break
# -> 2126             list.append(self.parseStatementListItem())
#    2127         return list
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parseStatementListItem(self)
#    2109                 return self.parsePyimportStatement()
# -> 2110         return self.parseStatement()
#    2111
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parseStatement(self)
#    2704
# -> 2705         expr = self.parseExpression()
#    2706
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parseExpression(self)
#    2075         startToken = self.lookahead
# -> 2076         expr = self.isolateCoverGrammar(self.parseAssignmentExpression)
#    2077
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in isolateCoverGrammar(self, parser)
#    1160         self.firstCoverInitializedNameError = null
# -> 1161         result = parser()
#    1162         if (self.firstCoverInitializedNameError != null):
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parseAssignmentExpression(self)
#    2037
# -> 2038         expr = self.parseConditionalExpression()
#    2039
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parseConditionalExpression(self)
#    1930
# -> 1931         expr = self.inheritCoverGrammar(self.parseBinaryExpression)
#    1932         if (self.match('?')):
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in inheritCoverGrammar(self, parser)
#    1175         self.firstCoverInitializedNameError = null
# -> 1176         result = parser()
#    1177         self.isBindingElement = self.isBindingElement and oldIsBindingElement
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parseBinaryExpression(self)
#    1875         marker = self.lookahead
# -> 1876         left = self.inheritCoverGrammar(self.parseUnaryExpression)
#    1877
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in inheritCoverGrammar(self, parser)
#    1175         self.firstCoverInitializedNameError = null
# -> 1176         result = parser()
#    1177         self.isBindingElement = self.isBindingElement and oldIsBindingElement
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parseUnaryExpression(self)
#    1817                 and self.lookahead['type'] != Token.Keyword):
# -> 1818             expr = self.parsePostfixExpression()
#    1819         elif (self.match('++') or self.match('--')):
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parsePostfixExpression(self)
#    1792
# -> 1793         expr = self.inheritCoverGrammar(
#    1794             self.parseLeftHandSideExpressionAllowCall)
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in inheritCoverGrammar(self, parser)
#    1175         self.firstCoverInitializedNameError = null
# -> 1176         result = parser()
#    1177         self.isBindingElement = self.isBindingElement and oldIsBindingElement
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parseLeftHandSideExpressionAllowCall(self)
#    1728                 self.isAssignmentTarget = false
# -> 1729                 args = self.parseArguments()
#    1730                 expr = WrappingNode(startToken).finishCallExpression(
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parseArguments(self)
#    1663                 args.append(
# -> 1664                     self.isolateCoverGrammar(self.parseAssignmentExpression))
#    1665                 if (self.match(')')):
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in isolateCoverGrammar(self, parser)
#    1160         self.firstCoverInitializedNameError = null
# -> 1161         result = parser()
#    1162         if (self.firstCoverInitializedNameError != null):
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parseAssignmentExpression(self)
#    2037
# -> 2038         expr = self.parseConditionalExpression()
#    2039
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parseConditionalExpression(self)
#    1930
# -> 1931         expr = self.inheritCoverGrammar(self.parseBinaryExpression)
#    1932         if (self.match('?')):
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in inheritCoverGrammar(self, parser)
#    1175         self.firstCoverInitializedNameError = null
# -> 1176         result = parser()
#    1177         self.isBindingElement = self.isBindingElement and oldIsBindingElement
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parseBinaryExpression(self)
#    1875         marker = self.lookahead
# -> 1876         left = self.inheritCoverGrammar(self.parseUnaryExpression)
#    1877
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in inheritCoverGrammar(self, parser)
#    1175         self.firstCoverInitializedNameError = null
# -> 1176         result = parser()
#    1177         self.isBindingElement = self.isBindingElement and oldIsBindingElement
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parseUnaryExpression(self)
#    1817                 and self.lookahead['type'] != Token.Keyword):
# -> 1818             expr = self.parsePostfixExpression()
#    1819         elif (self.match('++') or self.match('--')):
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parsePostfixExpression(self)
#    1792
# -> 1793         expr = self.inheritCoverGrammar(
#    1794             self.parseLeftHandSideExpressionAllowCall)
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in inheritCoverGrammar(self, parser)
#    1175         self.firstCoverInitializedNameError = null
# -> 1176         result = parser()
#    1177         self.isBindingElement = self.isBindingElement and oldIsBindingElement
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parseLeftHandSideExpressionAllowCall(self)
#    1715         else:
# -> 1716             expr = self.inheritCoverGrammar(
#    1717                 self.parseNewExpression if self.matchKeyword('new') else self.
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in inheritCoverGrammar(self, parser)
#    1175         self.firstCoverInitializedNameError = null
# -> 1176         result = parser()
#    1177         self.isBindingElement = self.isBindingElement and oldIsBindingElement
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parsePrimaryExpression(self)
#    1649         elif (typ == Token.Template):
# -> 1650             expr = self.parseTemplateLiteral()
#    1651         else:
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parseTemplateLiteral(self)
#    1508
# -> 1509         quasi = self.parseTemplateElement({'head': true})
#    1510         quasis = [quasi]
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parseTemplateElement(self, option)
#    1500
# -> 1501         return node.finishTemplateElement({
#    1502             'raw': token['value']['raw'],
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\std_nodes.py in __getattr__(self, item)
#     340             feature = item[6:]
# --> 341             raise Ecma51NotSupported(feature)
#     342         else:
#
# Ecma51NotSupported: TemplateElement is not supported by ECMA 5.1.
#
# During handling of the above exception, another exception occurred:
#
# JsException                               Traceback (most recent call last)
# <ipython-input-7-7d6bc43a964c> in <module>
# ----> 1 res_s = js2py.eval_js(sign)
#       2
#       3 print(res_s(0, 0x1b18cf7b9bd974a9b2f2c4d5c0b1c2f69022dc2b, 0xa48c6cc002b627954e1862620544e5613874676b, 5, default, 20))
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\js2py\evaljs.py in eval_js(js)
#     113        """
#     114     e = EvalJs()
# --> 115     return e.eval(js)
#     116
#     117
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\js2py\evaljs.py in eval(self, expression, use_compilation_plan)
#     202         """evaluates expression in current context and returns its value"""
#     203         code = 'PyJsEvalResult = eval(%s)' % json.dumps(expression)
# --> 204         self.execute(code, use_compilation_plan=use_compilation_plan)
#     205         return self['PyJsEvalResult']
#     206
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\js2py\evaljs.py in execute(self, js, use_compilation_plan)
#     197             compiled = cache[hashkey] = compile(code, '<EvalJS snippet>',
#     198                                                 'exec')
# --> 199         exec (compiled, self._context)
#     200
#     201     def eval(self, expression, use_compilation_plan=False):
#
# <EvalJS snippet> in <module>
#
# <EvalJS snippet> in PyJs_LONG_0_(var)
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\js2py\base.py in __call__(self, *args)
#     947             raise MakeError('TypeError',
#     948                             '%s is not a function' % self.typeof())
# --> 949         return self.call(self.GlobalObject, args)
#     950
#     951     def create(self, *args):
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\js2py\base.py in call(self, this, args)
#    1462         args += this, arguments  #append extra params to the arg list
#    1463         try:
# -> 1464             return Js(self.code(*args))
#    1465         except NotImplementedError:
#    1466             raise
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\js2py\host\jseval.py in Eval(code, this, arguments)
#      15     globals()['var'] = local_scope
#      16     try:
# ---> 17         py_code = translate_js(code.to_string().value, '')
#      18     except SyntaxError as syn_err:
#      19         raise MakeError('SyntaxError', str(syn_err))
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\js2py\translators\translator.py in translate_js(js, HEADER, use_compilation_plan, parse_fn)
#      68         return translate_js_with_compilation_plan(js, HEADER=HEADER)
#      69
# ---> 70     parsed = parse_fn(js)
#      71     translating_nodes.clean_stacks()
#      72     return HEADER + translating_nodes.trans(
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\js2py\translators\translator.py in pyjsparser_parse_fn(code)
#      60 def pyjsparser_parse_fn(code):
#      61     parser = pyjsparser.PyJsParser()
# ---> 62     return parser.parse(code)
#      63
#      64 def translate_js(js, HEADER=DEFAULT_HEADER, use_compilation_plan=False, parse_fn=pyjsparser_parse_fn):
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\pyjsparser\parser.py in parse(self, code, options)
#    3008             program = self.parseProgram()
#    3009         except Ecma51NotSupported as e:
# -> 3010             raise self.createError(self.lineNumber, self.lastIndex, unicode(e))
#    3011         return node_to_dict(program)
#    3012
#
# JsException: SyntaxError: Line 17: TemplateElement is not supported by ECMA 5.1.

# %%
ctx = MiniRacer()
ctx.eval(sign)
# Out:
# ---------------------------------------------------------------------------
# JSEvalException                           Traceback (most recent call last)
# <ipython-input-11-7d597b25d2e6> in <module>
#       1 ctx = MiniRacer()
# ----> 2 ctx.eval(sign)
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\py_mini_racer\py_mini_racer.py in eval(self, code, timeout, max_memory)
#     219             raise JSConversionException()
#     220
# --> 221         return MiniRacerValue(self, res).to_python()
#     222
#     223     def execute(self, expr, timeout=None, max_memory=None):
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\py_mini_racer\py_mini_racer.py in to_python(self)
#     401
#     402     def to_python(self):
# --> 403         self._raise_from_error()
#     404         result = None
#     405         typ = self.type
#
# D:\Programok_tenyleg\Anaconda\lib\site-packages\py_mini_racer\py_mini_racer.py in _raise_from_error(self)
#     392         elif self.type == MiniRacerTypes.execute_exception:
#     393             msg = ctypes.c_char_p(self.value).value
# --> 394             raise JSEvalException(msg.decode('utf-8', errors='replace'))
#     395         elif self.type == MiniRacerTypes.oom_exception:
#     396             msg = ctypes.c_char_p(self.value).value
#
# JSEvalException: Uncaught ReferenceError: require is not defined at undefined:2:15
# ReferenceError: require is not defined
#     at <anonymous>:2:16
